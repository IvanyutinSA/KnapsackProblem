# %% [markdown]
# ## Algorithm init

# %%
from algorithm.genetic import Genetic

genetic = Genetic()

# %% [markdown]
# ## Tests

# %%
from visual.visual import Visual
vis = Visual()

# %%
from tests.randomtests import Tests
test = Tests()

# %% [markdown]
# ## Dimension: 10

# %% [markdown]
# ### Random Multiple Attempts

# %%
from tests.randomtests import Tests
from visual.auxiliary import display_pairs

items = 10
attempts = 30

y_hat, y = test.RandomMultipleAttempts(items=items, attempts=attempts)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 348	348
# 94	348
# 142	348
# 145	348
# 96	348
# 235	348
# 138	348
# 95	348
# 95	348
# 95	348
# 93	348
# 95	348
# 96	348
# 140	348
# 93	348
# 95	348
# 95	348
# 112	348
# 95	348
# 136	348
# 93	348
# 47	348
# 142	348
# 95	348
# 95	348
# 153	348
# 138	348
# 95	348
# 95	348
# 95	348

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Multiple Cases

# %%
items = 10
cases = 30

y_hat, y = test.RandomMultipleCases(items=items, cases=cases)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 items = 10
#       2 cases = 30
# ----> 4 y_hat, y = test.RandomMultipleCases(items=items, cases=cases)
#       6 print("our\tlib")
#       7 display_pairs(y_hat, y)
#
# File c:\Users\Evgenii\WorkProg\Program\Проектная Деятельность 2 курс\KnapsackProblem\tests\randomtests.py:95, in Tests.RandomMultipleCases(self, items, cases)
#      93 lib_results = []
#      94 for _ in range(cases):
# ---> 95     genetic_value, lib_value = self.Random(items)
#      96     genetic_results.append(genetic_value)
#      97     lib_results.append(lib_value)
#
# File c:\Users\Evgenii\WorkProg\Program\Проектная Деятельность 2 курс\KnapsackProblem\tests\randomtests.py:36, in Tests.Random(self, items)
#      34 if os.path.isfile(f"rand_tests/Input{self.test_number}.txt"):
#      35     self.test_number += 1
# ---> 36 file_filling(f"rand_tests/Input{self.test_number}.txt")
#      38 genetic_result = genetic.solve(knapsack, capacity)[0]
#      40 lib.init(values, [weights], [capacity])
#
# File c:\Users\Evgenii\WorkProg\Program\Проектная Деятельность 2 курс\KnapsackProblem\tests\randomtests.py:29, in Tests.Random.<locals>.file_filling(path)
#      28 def file_filling(path):
# ---> 29             with open(path, 'a') as f:
#      30                         f.write(f"{len(values)} {capacity}\n")
#      31                         for i in range(len(values)):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rand_tests/Input-1.txt'

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Mixed

# %%
items = 10
cases = 15
attempts = 3

y_hat, y = test.RandomMultiple(items=items, cases=cases, attempts=attempts)

print("out\tlib")
display_pairs(y_hat, y)
# Out:
# out	lib
# 86	474
# 98	474
# 105	474
# 97	415
# 97	415
# 117	415
# 96	565
# 124	565
# 156	565
# 95	285
# 92	285
# 140	285
# 136	361
# 88	361
# 176	361
# 110	558
# 110	558
# 175	558
# 84	137
# 51	137
# 84	137
# 106	428
# 97	428
# 97	428
# 153	580
# 98	580
# 98	580
# 78	462
# 97	462
# 97	462
# 124	337
# 82	337
# 115	337
# 73	73
# 73	73
# 73	73
# 119	294
# 74	294
# 83	294
# 71	272
# 85	272
# 85	272
# 88	266
# 88	266
# 88	266

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Lib

# %%
from tests.lib_tests import lib_tests

y_hat, y = lib_tests()

print("out\tlib")
display_pairs(y_hat, y)
# Out:
# out	lib
# 10	10
# 100	100
# 1100	1100
# 1100	1100

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ## Bigger digits

# %% [markdown]
# ### Random Multiple Attempts

# %%
from tests.randomtests import Tests
from visual.auxiliary import display_pairs

items = 100
attempts = 300

y_hat, y = test.RandomMultipleAttempts(items=items, attempts=attempts)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 413	4723
# 380	4723
# 359	4723
# 326	4723
# 404	4723
# 313	4723
# 399	4723
# 407	4723
# 490	4723
# 400	4723
# 379	4723
# 351	4723
# 342	4723
# 403	4723
# 402	4723
# 267	4723
# 327	4723
# 378	4723
# 361	4723
# 322	4723
# 337	4723
# 297	4723
# 430	4723
# 311	4723
# 428	4723
# 325	4723
# 362	4723
# 413	4723
# 272	4723
# 487	4723
# 284	4723
# 450	4723
# 293	4723
# 383	4723
# 348	4723
# 325	4723
# 403	4723
# 398	4723
# 335	4723
# 347	4723
# 368	4723
# 374	4723
# 322	4723
# 317	4723
# 360	4723
# 475	4723
# 299	4723
# 281	4723
# 399	4723
# 328	4723
# 363	4723
# 262	4723
# 437	4723
# 348	4723
# 359	4723
# 369	4723
# 370	4723
# 339	4723
# 370	4723
# 356	4723
# 397	4723
# 323	4723
# 359	4723
# 377	4723
# 431	4723
# 485	4723
# 370	4723
# 316	4723
# 411	4723
# 350	4723
# 357	4723
# 402	4723
# 343	4723
# 284	4723
# 350	4723
# 307	4723
# 341	4723
# 396	4723
# 343	4723
# 264	4723
# 365	4723
# 299	4723
# 286	4723
# 369	4723
# 348	4723
# 380	4723
# 346	4723
# 337	4723
# 364	4723
# 355	4723
# 513	4723
# 374	4723
# 318	4723
# 402	4723
# 301	4723
# 394	4723
# 362	4723
# 368	4723
# 361	4723
# 404	4723
# 314	4723
# 305	4723
# 398	4723
# 331	4723
# 428	4723
# 334	4723
# 464	4723
# 425	4723
# 361	4723
# 419	4723
# 338	4723
# 351	4723
# 440	4723
# 347	4723
# 319	4723
# 447	4723
# 355	4723
# 395	4723
# 249	4723
# 429	4723
# 346	4723
# 314	4723
# 301	4723
# 311	4723
# 379	4723
# 312	4723
# 404	4723
# 367	4723
# 399	4723
# 330	4723
# 258	4723
# 347	4723
# 409	4723
# 323	4723
# 323	4723
# 370	4723
# 588	4723
# 408	4723
# 511	4723
# 353	4723
# 418	4723
# 340	4723
# 361	4723
# 312	4723
# 413	4723
# 340	4723
# 287	4723
# 474	4723
# 465	4723
# 409	4723
# 432	4723
# 265	4723
# 363	4723
# 368	4723
# 390	4723
# 295	4723
# 330	4723
# 275	4723
# 440	4723
# 330	4723
# 323	4723
# 432	4723
# 410	4723
# 420	4723
# 397	4723
# 308	4723
# 286	4723
# 398	4723
# 440	4723
# 425	4723
# 287	4723
# 353	4723
# 385	4723
# 322	4723
# 391	4723
# 405	4723
# 318	4723
# 356	4723
# 357	4723
# 388	4723
# 388	4723
# 315	4723
# 299	4723
# 299	4723
# 445	4723
# 359	4723
# 276	4723
# 345	4723
# 364	4723
# 467	4723
# 380	4723
# 449	4723
# 287	4723
# 302	4723
# 337	4723
# 338	4723
# 365	4723
# 392	4723
# 333	4723
# 462	4723
# 329	4723
# 331	4723
# 477	4723
# 331	4723
# 397	4723
# 388	4723
# 388	4723
# 394	4723
# 414	4723
# 309	4723
# 398	4723
# 312	4723
# 356	4723
# 392	4723
# 332	4723
# 365	4723
# 374	4723
# 472	4723
# 313	4723
# 313	4723
# 307	4723
# 355	4723
# 386	4723
# 275	4723
# 374	4723
# 289	4723
# 401	4723
# 414	4723
# 306	4723
# 380	4723
# 412	4723
# 411	4723
# 328	4723
# 387	4723
# 493	4723
# 344	4723
# 268	4723
# 414	4723
# 419	4723
# 371	4723
# 387	4723
# 319	4723
# 353	4723
# 258	4723
# 367	4723
# 434	4723
# 300	4723
# 243	4723
# 346	4723
# 335	4723
# 347	4723
# 309	4723
# 409	4723
# 428	4723
# 326	4723
# 344	4723
# 347	4723
# 387	4723
# 261	4723
# 346	4723
# 406	4723
# 461	4723
# 361	4723
# 381	4723
# 435	4723
# 390	4723
# 263	4723
# 446	4723
# 318	4723
# 341	4723
# 342	4723
# 402	4723
# 286	4723
# 323	4723
# 353	4723
# 358	4723
# 391	4723
# 354	4723
# 392	4723
# 329	4723
# 340	4723
# 314	4723
# 416	4723
# 374	4723
# 444	4723
# 391	4723
# 550	4723
# 333	4723
# 374	4723
# 480	4723
# 379	4723
# 352	4723
# 404	4723
# 347	4723
# 296	4723
# 425	4723
# 294	4723
# 454	4723
# 401	4723
# 362	4723

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Multiple Cases

# %%
items = 100
cases = 200

y_hat, y = test.RandomMultipleCases(items=items, cases=cases)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 391	4490
# 307	2155
# 324	5126
# 457	5335
# 272	1193
# 404	4513
# 361	5150
# 446	3292
# 418	4867
# 407	4499
# 362	4708
# 349	4067
# 349	3703
# 328	3249
# 327	4193
# 250	5248
# 265	4663
# 263	4447
# 358	3636
# 361	2233
# 285	4722
# 397	2264
# 417	1928
# 354	5228
# 471	4136
# 409	3805
# 378	5170
# 333	2895
# 311	5011
# 323	4436
# 365	3520
# 332	4452
# 350	3259
# 378	4541
# 504	3317
# 294	4862
# 362	2975
# 352	3390
# 229	3613
# 296	1896
# 362	3558
# 328	3451
# 373	3334
# 290	2590
# 367	4181
# 323	4508
# 366	4900
# 370	2411
# 410	5186
# 296	4140
# 389	5052
# 279	2818
# 362	2397
# 300	4877
# 322	4297
# 373	1770
# 288	3450
# 485	3994
# 338	1719
# 355	1705
# 308	4618
# 396	2426
# 381	3103
# 357	5118
# 358	2031
# 391	1340
# 399	4337
# 384	3945
# 305	4777
# 351	2951
# 364	4526
# 336	3480
# 173	814
# 322	1616
# 318	2883
# 402	2999
# 328	3153
# 340	3791
# 303	1285
# 314	4522
# 328	3712
# 434	4092
# 402	3550
# 291	3555
# 350	1458
# 372	4377
# 316	4088
# 324	3954
# 383	4995
# 399	2511
# 480	2082
# 489	4409
# 370	4531
# 349	1277
# 418	3689
# 312	2135
# 382	4768
# 410	3997
# 344	3681
# 322	4626
# 420	3990
# 420	5011
# 402	3577
# 324	4939
# 290	3527
# 337	4755
# 366	4518
# 428	4531
# 353	4991
# 436	3598
# 429	3424
# 611	2851
# 133	444
# 386	2042
# 325	4108
# 304	3769
# 59	157
# 347	2127
# 552	4376
# 365	4405
# 349	3302
# 279	4900
# 258	795
# 337	3250
# 430	5288
# 346	4626
# 270	1088
# 310	4801
# 313	2133
# 376	4925
# 302	5312
# 324	4986
# 339	4659
# 331	4978
# 347	4763
# 452	2195
# 329	3666
# 287	5066
# 390	3297
# 282	4358
# 234	2014
# 362	3074
# 439	5301
# 314	2138
# 288	1596
# 327	4894
# 327	3822
# 311	4514
# 472	4391
# 460	4180
# 344	4814
# 443	2869
# 270	1693
# 308	3772
# 396	2635
# 293	3112
# 360	5216
# 305	2072
# 426	2004
# 403	2068
# 241	3442
# 338	2077
# 371	3997
# 410	2655
# 312	1481
# 280	3265
# 486	4176
# 434	3435
# 441	3170
# 369	4920
# 330	3685
# 302	5356
# 292	4236
# 247	711
# 302	3919
# 396	4666
# 254	992
# 262	3510
# 339	4216
# 323	2421
# 384	5378
# 340	2812
# 343	3332
# 297	4509
# 299	4228
# 185	574
# 463	1617
# 349	2559
# 313	5591
# 332	4968
# 355	4702
# 347	3036
# 312	5007
# 362	2295
# 322	2667
# 322	2576
# 414	3168
# 551	4722
# 354	2191
# 435	2519

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Mixed

# %%
items = 100
cases = 30
attempts = 20

y_hat, y = test.RandomMultiple(items=items, cases=cases, attempts=attempts)

print("out\tlib")
display_pairs(y_hat, y)
# Out:
# out	lib
# 344	4567
# 411	4567
# 405	4567
# 367	4567
# 367	4567
# 403	4567
# 353	4567
# 496	4567
# 324	4567
# 384	4567
# 469	4567
# 362	4567
# 377	4567
# 330	4567
# 329	4567
# 316	4567
# 346	4567
# 344	4567
# 347	4567
# 320	4567
# 281	1057
# 290	1057
# 320	1057
# 221	1057
# 304	1057
# 307	1057
# 319	1057
# 246	1057
# 276	1057
# 263	1057
# 351	1057
# 341	1057
# 273	1057
# 288	1057
# 280	1057
# 241	1057
# 330	1057
# 309	1057
# 271	1057
# 357	1057
# 322	3226
# 310	3226
# 463	3226
# 334	3226
# 242	3226
# 341	3226
# 402	3226
# 355	3226
# 454	3226
# 347	3226
# 353	3226
# 307	3226
# 305	3226
# 392	3226
# 380	3226
# 343	3226
# 350	3226
# 334	3226
# 303	3226
# 299	3226
# 354	4540
# 375	4540
# 388	4540
# 342	4540
# 377	4540
# 235	4540
# 310	4540
# 285	4540
# 339	4540
# 380	4540
# 384	4540
# 342	4540
# 322	4540
# 276	4540
# 334	4540
# 270	4540
# 344	4540
# 354	4540
# 282	4540
# 346	4540
# 265	4673
# 366	4673
# 338	4673
# 309	4673
# 404	4673
# 268	4673
# 650	4673
# 425	4673
# 363	4673
# 376	4673
# 325	4673
# 591	4673
# 352	4673
# 336	4673
# 348	4673
# 393	4673
# 352	4673
# 357	4673
# 402	4673
# 406	4673
# 318	4931
# 408	4931
# 354	4931
# 366	4931
# 450	4931
# 376	4931
# 324	4931
# 340	4931
# 314	4931
# 351	4931
# 381	4931
# 314	4931
# 371	4931
# 393	4931
# 308	4931
# 470	4931
# 377	4931
# 352	4931
# 343	4931
# 368	4931
# 290	4803
# 315	4803
# 329	4803
# 333	4803
# 314	4803
# 283	4803
# 270	4803
# 321	4803
# 423	4803
# 412	4803
# 373	4803
# 434	4803
# 306	4803
# 308	4803
# 332	4803
# 306	4803
# 329	4803
# 379	4803
# 346	4803
# 386	4803
# 418	1988
# 275	1988
# 367	1988
# 357	1988
# 407	1988
# 466	1988
# 339	1988
# 328	1988
# 363	1988
# 331	1988
# 313	1988
# 388	1988
# 311	1988
# 407	1988
# 374	1988
# 335	1988
# 405	1988
# 359	1988
# 388	1988
# 443	1988
# 399	1401
# 275	1401
# 365	1401
# 329	1401
# 325	1401
# 336	1401
# 315	1401
# 365	1401
# 315	1401
# 339	1401
# 375	1401
# 313	1401
# 346	1401
# 359	1401
# 369	1401
# 446	1401
# 383	1401
# 328	1401
# 290	1401
# 286	1401
# 265	4249
# 332	4249
# 431	4249
# 311	4249
# 386	4249
# 283	4249
# 236	4249
# 329	4249
# 378	4249
# 346	4249
# 311	4249
# 258	4249
# 344	4249
# 330	4249
# 311	4249
# 366	4249
# 460	4249
# 352	4249
# 339	4249
# 356	4249
# 379	4513
# 404	4513
# 493	4513
# 338	4513
# 398	4513
# 364	4513
# 318	4513
# 452	4513
# 393	4513
# 319	4513
# 431	4513
# 354	4513
# 296	4513
# 306	4513
# 370	4513
# 476	4513
# 373	4513
# 341	4513
# 322	4513
# 439	4513
# 358	4530
# 280	4530
# 392	4530
# 296	4530
# 387	4530
# 416	4530
# 296	4530
# 326	4530
# 336	4530
# 433	4530
# 456	4530
# 366	4530
# 371	4530
# 281	4530
# 367	4530
# 319	4530
# 329	4530
# 377	4530
# 488	4530
# 315	4530
# 436	3026
# 465	3026
# 358	3026
# 333	3026
# 510	3026
# 439	3026
# 338	3026
# 383	3026
# 344	3026
# 350	3026
# 401	3026
# 403	3026
# 440	3026
# 319	3026
# 362	3026
# 429	3026
# 330	3026
# 312	3026
# 350	3026
# 404	3026
# 387	3911
# 382	3911
# 345	3911
# 383	3911
# 337	3911
# 455	3911
# 287	3911
# 442	3911
# 301	3911
# 292	3911
# 317	3911
# 369	3911
# 386	3911
# 411	3911
# 336	3911
# 350	3911
# 438	3911
# 397	3911
# 318	3911
# 413	3911
# 284	4839
# 347	4839
# 339	4839
# 375	4839
# 276	4839
# 283	4839
# 392	4839
# 413	4839
# 349	4839
# 300	4839
# 369	4839
# 309	4839
# 367	4839
# 450	4839
# 279	4839
# 439	4839
# 280	4839
# 330	4839
# 334	4839
# 368	4839
# 372	4477
# 381	4477
# 267	4477
# 235	4477
# 305	4477
# 454	4477
# 370	4477
# 418	4477
# 330	4477
# 308	4477
# 304	4477
# 462	4477
# 326	4477
# 363	4477
# 351	4477
# 337	4477
# 314	4477
# 244	4477
# 319	4477
# 353	4477
# 290	3515
# 314	3515
# 380	3515
# 324	3515
# 374	3515
# 375	3515
# 353	3515
# 358	3515
# 289	3515
# 365	3515
# 321	3515
# 359	3515
# 276	3515
# 324	3515
# 406	3515
# 318	3515
# 232	3515
# 265	3515
# 322	3515
# 308	3515
# 384	3711
# 276	3711
# 348	3711
# 358	3711
# 307	3711
# 259	3711
# 311	3711
# 266	3711
# 389	3711
# 294	3711
# 316	3711
# 327	3711
# 337	3711
# 316	3711
# 364	3711
# 324	3711
# 501	3711
# 336	3711
# 456	3711
# 246	3711
# 314	4931
# 297	4931
# 386	4931
# 339	4931
# 315	4931
# 388	4931
# 364	4931
# 361	4931
# 417	4931
# 295	4931
# 373	4931
# 397	4931
# 314	4931
# 332	4931
# 280	4931
# 500	4931
# 370	4931
# 326	4931
# 348	4931
# 225	4931
# 298	4379
# 282	4379
# 417	4379
# 276	4379
# 372	4379
# 438	4379
# 462	4379
# 342	4379
# 328	4379
# 245	4379
# 384	4379
# 340	4379
# 383	4379
# 324	4379
# 290	4379
# 400	4379
# 398	4379
# 323	4379
# 317	4379
# 263	4379
# 211	583
# 173	583
# 204	583
# 249	583
# 178	583
# 175	583
# 185	583
# 215	583
# 205	583
# 115	583
# 167	583
# 195	583
# 211	583
# 224	583
# 190	583
# 252	583
# 177	583
# 189	583
# 263	583
# 181	583
# 335	5086
# 356	5086
# 459	5086
# 340	5086
# 300	5086
# 340	5086
# 338	5086
# 343	5086
# 385	5086
# 288	5086
# 459	5086
# 311	5086
# 479	5086
# 342	5086
# 361	5086
# 245	5086
# 391	5086
# 295	5086
# 430	5086
# 384	5086
# 363	2289
# 323	2289
# 317	2289
# 502	2289
# 294	2289
# 351	2289
# 435	2289
# 377	2289
# 281	2289
# 502	2289
# 373	2289
# 318	2289
# 348	2289
# 369	2289
# 301	2289
# 324	2289
# 315	2289
# 391	2289
# 356	2289
# 362	2289
# 319	2778
# 395	2778
# 381	2778
# 463	2778
# 312	2778
# 404	2778
# 350	2778
# 429	2778
# 312	2778
# 305	2778
# 239	2778
# 377	2778
# 334	2778
# 384	2778
# 379	2778
# 414	2778
# 347	2778
# 354	2778
# 471	2778
# 394	2778
# 346	4583
# 342	4583
# 332	4583
# 381	4583
# 278	4583
# 339	4583
# 283	4583
# 325	4583
# 279	4583
# 415	4583
# 365	4583
# 401	4583
# 297	4583
# 423	4583
# 450	4583
# 345	4583
# 387	4583
# 445	4583
# 427	4583
# 281	4583
# 303	3564
# 353	3564
# 323	3564
# 302	3564
# 287	3564
# 394	3564
# 315	3564
# 333	3564
# 319	3564
# 441	3564
# 335	3564
# 360	3564
# 267	3564
# 320	3564
# 428	3564
# 289	3564
# 369	3564
# 432	3564
# 364	3564
# 389	3564
# 357	5067
# 313	5067
# 301	5067
# 373	5067
# 344	5067
# 517	5067
# 427	5067
# 333	5067
# 359	5067
# 330	5067
# 317	5067
# 386	5067
# 389	5067
# 307	5067
# 311	5067
# 333	5067
# 306	5067
# 439	5067
# 395	5067
# 345	5067
# 356	4733
# 368	4733
# 314	4733
# 343	4733
# 362	4733
# 279	4733
# 308	4733
# 303	4733
# 317	4733
# 335	4733
# 274	4733
# 321	4733
# 305	4733
# 300	4733
# 361	4733
# 314	4733
# 297	4733
# 300	4733
# 361	4733
# 346	4733
# 493	2980
# 347	2980
# 409	2980
# 356	2980
# 473	2980
# 285	2980
# 414	2980
# 364	2980
# 326	2980
# 374	2980
# 316	2980
# 365	2980
# 436	2980
# 327	2980
# 374	2980
# 328	2980
# 363	2980
# 331	2980
# 407	2980
# 336	2980
# 309	4525
# 334	4525
# 305	4525
# 380	4525
# 446	4525
# 390	4525
# 352	4525
# 343	4525
# 318	4525
# 373	4525
# 303	4525
# 360	4525
# 386	4525
# 303	4525
# 353	4525
# 266	4525
# 331	4525
# 309	4525
# 422	4525
# 313	4525

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Lib

# %%
from tests.lib_tests import lib_tests

y_hat, lib_results, y = lib_tests()

print("our_alg\tlib_alg\tcorrect")
display_pairs(y_hat, lib_results, y)
# Out:
# our_alg	lib_alg	correct
# 10	10	10
# 100	100	100
# 1000	1100	1100
# 550	1100	1100
# 137	295	295
# 154	1024	1024
# 432	3103	3103
# 560	5183	5183
# 1444	15170	15170

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %%
#пример графика со временем
import numpy as np
time_gen=np.round(np.random.rand(100),3)
time_lib=np.round(np.random.rand(100),3)
display_pairs(time_gen, time_lib)
vis.Time_Grafik(time_gen, time_lib)
vis.Time_Grafik_Math(time_gen, time_lib)
# Out:
# 0.887	0.614
# 0.554	0.259
# 0.368	0.655
# 0.918	0.519
# 0.335	0.149
# 0.903	0.611
# 0.753	0.529
# 0.216	0.49
# 0.729	0.619
# 0.796	0.763
# 0.528	0.821
# 0.882	0.815
# 0.105	0.251
# 0.783	0.602
# 0.709	0.479
# 0.738	0.659
# 0.832	0.749
# 0.512	0.557
# 0.479	0.519
# 0.25	0.429
# 0.476	0.097
# 0.359	0.256
# 0.275	0.944
# 0.34	0.236
# 0.245	0.011
# 0.549	0.582
# 0.308	0.034
# 0.07	0.699
# 0.863	0.646
# 0.259	0.281
# 0.786	0.498
# 0.541	0.946
# 0.376	0.316
# 0.173	0.736
# 0.785	0.544
# 0.619	0.383
# 0.635	0.851
# 0.634	0.196
# 0.288	0.553
# 0.581	0.02
# 0.212	0.457
# 0.69	0.946
# 0.513	0.366
# 0.32	0.864
# 0.582	0.924
# 0.438	0.865
# 0.284	0.991
# 0.964	0.805
# 0.596	0.476
# 0.854	0.247
# 0.531	0.66
# 0.822	0.267
# 0.657	0.003
# 0.912	0.79
# 0.627	0.292
# 0.248	0.84
# 0.954	0.882
# 0.004	0.589
# 0.838	0.871
# 0.512	0.119
# 0.209	0.213
# 0.96	0.01
# 0.029	0.465
# 0.209	0.939
# 0.272	0.593
# 0.772	0.182
# 0.276	0.497
# 0.676	0.335
# 0.823	0.266
# 0.794	0.221
# 0.041	0.914
# 0.549	0.188
# 0.912	0.5
# 0.452	0.697
# 0.268	0.711
# 0.223	0.511
# 0.536	0.193
# 0.331	0.886
# 0.321	0.391
# 0.036	0.08
# 0.12	0.612
# 0.316	0.688
# 0.638	0.351
# 0.484	0.214
# 0.373	0.394
# 0.545	0.277
# 0.297	0.532
# 0.361	0.965
# 0.928	0.639
# 0.134	0.253
# 0.407	0.816
# 0.917	0.051
# 0.825	0.415
# 0.972	0.892
# 0.494	0.885
# 0.428	0.761
# 0.344	0.03
# 0.772	0.188
# 0.056	0.459
# 0.723	0.958

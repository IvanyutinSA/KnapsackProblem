# %% [markdown]
# ## Algorithm init

# %%
from algorithm.genetic import Genetic

genetic = Genetic()

# %% [markdown]
# ## Tests

# %%
from visual.visual import Visual
vis = Visual()

# %%
from tests.randomtests import Tests
test = Tests()

# %% [markdown]
# ## Dimension: 10

# %% [markdown]
# ### Random Multiple Attempts

# %%
from tests.randomtests import Tests
from visual.auxiliary import display_pairs

items = 10
attempts = 30

y_hat, y, gen_times, lib_times = test.RandomMultipleAttempts(items=items, attempts=attempts)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 112	112
# 66	112
# 46	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 31	112
# 66	112
# 66	112
# 46	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 66	112
# 97	112
# 46	112

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Multiple Cases

# %%
items = 10
cases = 30

y_hat, y, gen_times1, lib_times1 = test.RandomMultipleCases(items=items, cases=cases)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 80	470
# 98	407
# 178	531
# 115	276
# 159	281
# 166	558
# 106	500
# 156	178
# 127	254
# 90	362
# 98	362
# 68	136
# 109	308
# 128	429
# 104	286
# 66	66
# 86	86
# 111	336
# 97	97
# 122	533
# 173	551
# 148	434
# 127	398
# 98	278
# 97	603
# 150	279
# 142	331
# 97	512
# 100	309
# 61	154

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Mixed

# %%
items = 10
cases = 15
attempts = 3

y_hat, y, gen_times2, lib_times2 = test.RandomMultiple(items=items, cases=cases, attempts=attempts)

print("out\tlib")
display_pairs(y_hat, y)
# Out:
# out	lib
# 98	98
# 93	98
# 98	98
# 144	279
# 127	279
# 107	279
# 141	230
# 94	230
# 98	230
# 90	521
# 102	521
# 90	521
# 165	431
# 97	431
# 91	431
# 93	336
# 93	336
# 93	336
# 91	91
# 91	91
# 91	91
# 124	473
# 86	473
# 156	473
# 94	304
# 112	304
# 112	304
# 192	491
# 93	491
# 157	491
# 92	176
# 133	176
# 92	176
# 131	362
# 85	362
# 85	362
# 99	410
# 145	410
# 99	410
# 99	450
# 99	450
# 99	450
# 137	454
# 139	454
# 212	454

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Lib

# %%
from tests.lib_tests import lib_tests

y_hat, y, answers, gen_time, lib_time = lib_tests()

print("lib\tour\tcorrect")
display_pairs(y_hat, y, answers)
# Out:
# lib	our	correct
# 10	10	10
# 100	100	100
# 1000	1100	1100
# 1100	1100	1100
# 87	295	295
# 181	1024	1024
# 682	3103	3103
# 441	5183	5183
# 1105	15170	15170

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ## Bigger digits

# %% [markdown]
# ### Random Multiple Attempts

# %%
from tests.randomtests import Tests
from visual.auxiliary import display_pairs

items = 100
attempts = 300

y_hat, y, gen_times, lib_times = test.RandomMultipleAttempts(items=items, attempts=attempts)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 396	2464
# 413	2464
# 366	2464
# 334	2464
# 354	2464
# 353	2464
# 370	2464
# 255	2464
# 308	2464
# 425	2464
# 376	2464
# 310	2464
# 382	2464
# 385	2464
# 352	2464
# 349	2464
# 311	2464
# 351	2464
# 295	2464
# 343	2464
# 355	2464
# 389	2464
# 384	2464
# 306	2464
# 343	2464
# 327	2464
# 300	2464
# 393	2464
# 321	2464
# 325	2464
# 282	2464
# 335	2464
# 318	2464
# 256	2464
# 317	2464
# 535	2464
# 350	2464
# 359	2464
# 422	2464
# 385	2464
# 416	2464
# 363	2464
# 328	2464
# 404	2464
# 342	2464
# 366	2464
# 396	2464
# 299	2464
# 413	2464
# 324	2464
# 407	2464
# 348	2464
# 369	2464
# 382	2464
# 398	2464
# 575	2464
# 375	2464
# 557	2464
# 380	2464
# 409	2464
# 357	2464
# 346	2464
# 465	2464
# 349	2464
# 283	2464
# 350	2464
# 287	2464
# 347	2464
# 330	2464
# 366	2464
# 330	2464
# 442	2464
# 353	2464
# 361	2464
# 290	2464
# 334	2464
# 327	2464
# 391	2464
# 383	2464
# 374	2464
# 376	2464
# 467	2464
# 372	2464
# 340	2464
# 439	2464
# 315	2464
# 312	2464
# 401	2464
# 351	2464
# 354	2464
# ...

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Multiple Cases

# %%
items = 100
cases = 200

y_hat, y, gen_times, lib_times  = test.RandomMultipleCases(items=items, cases=cases)

print("our\tlib")
display_pairs(y_hat, y)
# Out:
# our	lib
# 469	4687
# 397	3276
# 417	2475
# 400	4129
# 423	4485
# 353	4974
# 340	3452
# 336	4683
# 311	4375
# 364	3150
# 358	4848
# 347	1900
# 439	3651
# 455	5085
# 379	1618
# 307	3954
# 437	3633
# 365	4821
# 413	3953
# 294	4626
# 362	5374
# 334	4637
# 268	4316
# 443	2412
# 321	4709
# 374	3686
# 452	5028
# 463	3642
# 354	4953
# 430	4696
# 449	2120
# 151	689
# 299	2452
# 322	3200
# 454	1983
# 276	2668
# 343	4970
# 366	2851
# 379	4736
# 351	2524
# 354	3092
# 320	4691
# 348	4235
# 336	3289
# 323	3672
# 247	4095
# 397	3359
# 413	5049
# 355	3997
# 373	4724
# 279	4308
# 448	3700
# 318	2490
# 380	4846
# 309	4169
# 366	4659
# 332	2907
# 399	5080
# 323	4679
# 305	970
# 184	657
# 366	3775
# 515	5025
# 353	3104
# 308	5135
# 380	3979
# 344	2324
# 256	1783
# 350	3275
# 360	3244
# 372	4416
# 296	5390
# 208	588
# 387	3260
# 320	2174
# 342	1188
# 277	2736
# 247	1060
# 346	4836
# 431	2471
# 353	4296
# 365	5316
# 316	4833
# 356	4118
# 393	3159
# 402	5134
# 292	4805
# 339	5083
# 459	3429
# 308	4636
# ...

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Random Mixed

# %%
items = 100
cases = 30
attempts = 20

y_hat, y, gen_times, lib_times  = test.RandomMultiple(items=items, cases=cases, attempts=attempts)

print("out\tlib")
display_pairs(y_hat, y)
# Out:
# out	lib
# 400	2452
# 461	2452
# 341	2452
# 275	2452
# 349	2452
# 359	2452
# 336	2452
# 318	2452
# 272	2452
# 259	2452
# 349	2452
# 286	2452
# 364	2452
# 381	2452
# 366	2452
# 332	2452
# 292	2452
# 347	2452
# 461	2452
# 342	2452
# 288	3495
# 384	3495
# 365	3495
# 339	3495
# 341	3495
# 299	3495
# 354	3495
# 396	3495
# 392	3495
# 331	3495
# 357	3495
# 403	3495
# 391	3495
# 447	3495
# 482	3495
# 332	3495
# 442	3495
# 283	3495
# 374	3495
# 392	3495
# 394	3616
# 296	3616
# 325	3616
# 344	3616
# 332	3616
# 455	3616
# 425	3616
# 374	3616
# 365	3616
# 399	3616
# 295	3616
# 297	3616
# 345	3616
# 396	3616
# 391	3616
# 296	3616
# 308	3616
# 363	3616
# 424	3616
# 283	3616
# 408	4906
# 350	4906
# 364	4906
# 347	4906
# 487	4906
# 368	4906
# 340	4906
# 313	4906
# 354	4906
# 297	4906
# 318	4906
# 276	4906
# 460	4906
# 369	4906
# 290	4906
# 297	4906
# 268	4906
# 344	4906
# 349	4906
# 321	4906
# 300	3122
# 359	3122
# 270	3122
# 316	3122
# 282	3122
# 424	3122
# 212	3122
# 258	3122
# 268	3122
# 346	3122
# ...

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %% [markdown]
# ### Lib

# %%
from tests.lib_tests import lib_tests

y_hat, y, answers, gen_times, lib_times = lib_tests()

print("our_alg\tlib_alg\tcorrect")
display_pairs(y_hat, y, answers)
# Out:
# our_alg	lib_alg	correct
# 7	10	10
# 100	100	100
# 1000	1100	1100
# 1100	1100	1100
# 87	295	295
# 238	1024	1024
# 464	3103	3103
# 596	5183	5183
# 1155	15170	15170

# %%
vis.ResultPlot(y_hat, y)
vis.MatchPlot(y_hat, y)

# %%
print(gen_times)
# Out:
# [440, 288, 311, 311, 368, 1066, 2579, 3043, 5072]

# %%
#пример графика со временем
import numpy as np
# time_gen=np.round(np.random.rand(100),3)
# time_lib=np.round(np.random.rand(100),3)
# time_gen = 
# lib_times
display_pairs(gen_times, lib_times)
vis.Time_Grafik(gen_times, lib_times)
vis.Time_Grafik_Math(gen_times, lib_times)
# Out:
# 440	11
# 288	6
# 311	11
# 311	7
# 368	13
# 1066	12
# 2579	23
# 3043	32
# 5072	9
